# %%
import numpy as np

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_excel("Dataset.xlsx")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11565 entries, 0 to 11564
# Data columns (total 34 columns):
# Month                   11565 non-null object
# WeekOfMonth             11565 non-null int64
# DayOfWeek               11565 non-null object
# Make                    11565 non-null object
# AccidentArea            11565 non-null object
# DayOfWeekClaimed        11565 non-null object
# MonthClaimed            11565 non-null object
# WeekOfMonthClaimed      11565 non-null int64
# Sex                     11565 non-null object
# MaritalStatus           11565 non-null object
# Age                     11560 non-null float64
# Fault                   11565 non-null object
# PolicyType              11565 non-null object
# VehicleCategory         11565 non-null object
# VehiclePrice            11565 non-null object
# FraudFound_P            11565 non-null int64
# PolicyNumber            11565 non-null int64
# RepNumber               11565 non-null int64
# ...

# %%
df.head()
# Out:
#   Month  WeekOfMonth  DayOfWeek    Make AccidentArea DayOfWeekClaimed  \
# 0   Dec            5  Wednesday   Honda        Urban          Tuesday
# 1   Jan            3  Wednesday   Honda        Urban           Monday
# 2   Oct            5     Friday   Honda        Urban         Thursday
# 3   Jun            2   Saturday  Toyota        Rural           Friday
# 4   Feb            1   Saturday   Honda        Urban           Monday
#
#   MonthClaimed  WeekOfMonthClaimed     Sex MaritalStatus      ...       \
# 0          Jan                   1  Female        Single      ...
# 1          Jan                   4    Male        Single      ...
# 2          Nov                   2    Male       Married      ...
# 3          Jul                   1    Male       Married      ...
# 4          Feb                   3    Male       Married      ...
#
#    AgeOfPolicyHolder PoliceReportFiled WitnessPresent AgentType  \
# 0           26 to 30                No             No  External
# ...

# %%
df.columns
# Out:
# Index(['Month', 'WeekOfMonth', 'DayOfWeek', 'Make', 'AccidentArea',
#        'DayOfWeekClaimed', 'MonthClaimed', 'WeekOfMonthClaimed', 'Sex',
#        'MaritalStatus', 'Age', 'Fault', 'PolicyType', 'VehicleCategory',
#        'VehiclePrice', 'FraudFound_P', 'PolicyNumber', 'RepNumber',
#        'Deductible', 'DriverRating', 'Days_Policy_Accident',
#        'Days_Policy_Claim', 'PastNumberOfClaims', 'AgeOfVehicle',
#        'AgeOfPolicyHolder', 'PoliceReportFiled', 'WitnessPresent', 'AgentType',
#        'NumberOfSuppliments', 'AddressChange_Claim', 'NumberOfCars', 'Year',
#        'BasePolicy', 'ClaimSize'],
#       dtype='object')

# %%
df['FraudFound_P'].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: FraudFound_P, dtype: int64

# %%
pd.get_dummies(df).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11565 entries, 0 to 11564
# Columns: 150 entries, WeekOfMonth to BasePolicy_Liability
# dtypes: float64(3), int64(7), uint8(140)
# memory usage: 2.4 MB

# %%
sns.distplot(df['ClaimSize'])

# %%
df.describe()
# Out:
#         WeekOfMonth  WeekOfMonthClaimed           Age  FraudFound_P  \
# count  11565.000000        11565.000000  11560.000000  11565.000000
# mean       2.784003            2.701167     39.899567      0.059230
# std        1.284854            1.258153     13.590556      0.236066
# min        1.000000            1.000000      0.000000      0.000000
# 25%        2.000000            2.000000     31.000000      0.000000
# 50%        3.000000            3.000000     38.000000      0.000000
# 75%        4.000000            4.000000     49.000000      0.000000
# max        5.000000            5.000000     80.000000      1.000000
#
#        PolicyNumber     RepNumber    Deductible  DriverRating          Year  \
# count  11565.000000  11565.000000  11565.000000  11559.000000  11565.000000
# mean    7710.474449      8.469780    407.617812      2.493468   1994.865975
# std     4453.762219      4.618952     43.397393      1.118102      0.801798
# ...

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
sns.heatmap(df.drop('PolicyNumber',axis=1).corr(),cmap='coolwarm',linecolor='black')

# %%
df.dropna(inplace=True)

# %%
X=pd.get_dummies(df.drop('FraudFound_P',axis=1))

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11554 entries, 0 to 11564
# Columns: 149 entries, WeekOfMonth to BasePolicy_Liability
# dtypes: float64(3), int64(6), uint8(140)
# memory usage: 2.4 MB

# %%
y=df['FraudFound_P']

# %%
X.head()
# Out:
#    WeekOfMonth  WeekOfMonthClaimed   Age  PolicyNumber  RepNumber  Deductible  \
# 0            5                   1  21.0             1         12         300
# 1            3                   4  34.0             2         15         400
# 2            5                   2  47.0             3          7         400
# 3            2                   1  65.0             4          4         400
# 4            1                   3  36.0             7         14         400
#
#    DriverRating  Year     ClaimSize  Month_Apr          ...           \
# 0           1.0  1994  55526.069421          0          ...
# 1           4.0  1994  59294.455571          0          ...
# 2           3.0  1994  71756.941320          0          ...
# 3           2.0  1994   7584.153493          0          ...
# 4           1.0  1994  98545.374339          0          ...
#
#    AddressChange_Claim_no change  AddressChange_Claim_under 6 months  \
# ...

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: FraudFound_P, dtype: int64

# %%
from sklearn.cross_validation import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
lmodel=DecisionTreeClassifier()

# %%
lmodel.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
prediction=lmodel.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

# %%
print(confusion_matrix(y_test,prediction))
# Out:
# [[5121  289]
#  [ 292   75]]

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,prediction))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.95      0.95      0.95      5410
#           1       0.21      0.20      0.21       367
#
# avg / total       0.90      0.90      0.90      5777

# %%
sns.pairplot(df)

# %%
X.to_excel("dataset3.xlsx",sheet_name='new_sheet')
